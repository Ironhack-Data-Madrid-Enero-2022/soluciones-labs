# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os
from dotenv import load_dotenv
import json
import requests
import re
load_dotenv()
# Out:
# True

# %%
#here we specify the endopoint for our request
#We need the endpoint for the specific repository
end_forks = "/repos/Ironhack-Data-Madrid-Enero-2022/apuntes_clase/forks"

# %%
def requestGithub (endpoint):
    
    
    '''This function get an endopoint as argument and returns a list with the response from GitHub API.
    It imports the github token from the .env file(not uploaded to github) and gets the authentication ready.s
    If you don't have your token in the .env file, it will raise an error.
    The function takes the base url https://api.github.com for github API and adds the endpoint that gets as argument'''
    
    
    token = os.getenv("GITHUB_APIKEY")
    if not token:
        raise ValueError ("Necesitas un token")
    direccion="https://api.github.com"
    url = direccion+endpoint

    print(f"Haciendo request a {url}")
    headers = {
        "Authorization": f"token {token}"}

    res = requests.get(url, headers=headers)
    return res.json()

# %%
forks = requestGithub(end_forks) #We call the function to make the request
# Out:
# Haciendo request a https://api.github.com/repos/Ironhack-Data-Madrid-Enero-2022/apuntes_clase/forks

# %%
forks 
#this is the info we get, now we have to dive inside the list of dictionaries to find the languages
# Out:
# [{'id': 454734190,
#   'node_id': 'R_kgDOGxqxbg',
#   'name': 'apuntes_clase',
#   'full_name': 'VictorPablo12/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'VictorPablo12',
#    'id': 94057227,
#    'node_id': 'U_kgDOBZszCw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94057227?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VictorPablo12',
#    'html_url': 'https://github.com/VictorPablo12',
#    'followers_url': 'https://api.github.com/users/VictorPablo12/followers',
#    'following_url': 'https://api.github.com/users/VictorPablo12/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/VictorPablo12/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/VictorPablo12/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/VictorPablo12/subscriptions',
#    'organizations_url': 'https://api.github.com/users/VictorPablo12/orgs',
#    'repos_url': 'https://api.github.com/users/VictorPablo12/repos',
#    'events_url': 'https://api.github.com/users/VictorPablo12/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/VictorPablo12/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/VictorPablo12/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/VictorPablo12/apuntes_clase/deployments',
#   'created_at': '2022-02-02T10:42:38Z',
#   'updated_at': '2022-01-10T12:36:54Z',
#   'pushed_at': '2022-02-02T10:03:05Z',
#   'git_url': 'git://github.com/VictorPablo12/apuntes_clase.git',
#   'ssh_url': 'git@github.com:VictorPablo12/apuntes_clase.git',
#   'clone_url': 'https://github.com/VictorPablo12/apuntes_clase.git',
#   'svn_url': 'https://github.com/VictorPablo12/apuntes_clase',
#   'homepage': None,
#   'size': 60868,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 454426232,
#   'node_id': 'R_kgDOGxX-eA',
#   'name': 'apuntes_clase',
#   'full_name': 'Marilyn499/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'Marilyn499',
#    'id': 57353265,
#    'node_id': 'MDQ6VXNlcjU3MzUzMjY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57353265?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Marilyn499',
#    'html_url': 'https://github.com/Marilyn499',
#    'followers_url': 'https://api.github.com/users/Marilyn499/followers',
#    'following_url': 'https://api.github.com/users/Marilyn499/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Marilyn499/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Marilyn499/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Marilyn499/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Marilyn499/orgs',
#    'repos_url': 'https://api.github.com/users/Marilyn499/repos',
#    'events_url': 'https://api.github.com/users/Marilyn499/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Marilyn499/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/Marilyn499/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Marilyn499/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Marilyn499/apuntes_clase/deployments',
#   'created_at': '2022-02-01T14:47:05Z',
#   'updated_at': '2022-02-02T08:04:49Z',
#   'pushed_at': '2022-02-02T08:04:41Z',
#   'git_url': 'git://github.com/Marilyn499/apuntes_clase.git',
#   'ssh_url': 'git@github.com:Marilyn499/apuntes_clase.git',
#   'clone_url': 'https://github.com/Marilyn499/apuntes_clase.git',
#   'svn_url': 'https://github.com/Marilyn499/apuntes_clase',
#   'homepage': None,
#   'size': 60716,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 450045830,
#   'node_id': 'R_kgDOGtMnhg',
#   'name': 'apuntes_clase',
#   'full_name': 'AntonioLopga12/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'AntonioLopga12',
#    'id': 95697009,
#    'node_id': 'U_kgDOBbQ4cQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95697009?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AntonioLopga12',
#    'html_url': 'https://github.com/AntonioLopga12',
#    'followers_url': 'https://api.github.com/users/AntonioLopga12/followers',
#    'following_url': 'https://api.github.com/users/AntonioLopga12/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/AntonioLopga12/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/AntonioLopga12/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/AntonioLopga12/subscriptions',
#    'organizations_url': 'https://api.github.com/users/AntonioLopga12/orgs',
#    'repos_url': 'https://api.github.com/users/AntonioLopga12/repos',
#    'events_url': 'https://api.github.com/users/AntonioLopga12/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/AntonioLopga12/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/AntonioLopga12/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/AntonioLopga12/apuntes_clase/deployments',
#   'created_at': '2022-01-20T10:11:50Z',
#   'updated_at': '2022-01-28T08:10:30Z',
#   'pushed_at': '2022-02-01T11:38:54Z',
#   'git_url': 'git://github.com/AntonioLopga12/apuntes_clase.git',
#   'ssh_url': 'git@github.com:AntonioLopga12/apuntes_clase.git',
#   'clone_url': 'https://github.com/AntonioLopga12/apuntes_clase.git',
#   'svn_url': 'https://github.com/AntonioLopga12/apuntes_clase',
#   'homepage': None,
#   'size': 36648,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 449774630,
#   'node_id': 'R_kgDOGs8EJg',
#   'name': 'apuntes_clase',
#   'full_name': 'mariozapatero/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'mariozapatero',
#    'id': 96702233,
#    'node_id': 'U_kgDOBcOPGQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96702233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mariozapatero',
#    'html_url': 'https://github.com/mariozapatero',
#    'followers_url': 'https://api.github.com/users/mariozapatero/followers',
#    'following_url': 'https://api.github.com/users/mariozapatero/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mariozapatero/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mariozapatero/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mariozapatero/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mariozapatero/orgs',
#    'repos_url': 'https://api.github.com/users/mariozapatero/repos',
#    'events_url': 'https://api.github.com/users/mariozapatero/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mariozapatero/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/mariozapatero/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/mariozapatero/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/mariozapatero/apuntes_clase/deployments',
#   'created_at': '2022-01-19T16:43:01Z',
#   'updated_at': '2022-01-25T14:47:24Z',
#   'pushed_at': '2022-01-28T13:34:15Z',
#   'git_url': 'git://github.com/mariozapatero/apuntes_clase.git',
#   'ssh_url': 'git@github.com:mariozapatero/apuntes_clase.git',
#   'clone_url': 'https://github.com/mariozapatero/apuntes_clase.git',
#   'svn_url': 'https://github.com/mariozapatero/apuntes_clase',
#   'homepage': None,
#   'size': 33266,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 449199202,
#   'node_id': 'R_kgDOGsY8Yg',
#   'name': 'apuntes_clase',
#   'full_name': 'DiSanchz/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'DiSanchz',
#    'id': 91422739,
#    'node_id': 'MDQ6VXNlcjkxNDIyNzM5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91422739?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DiSanchz',
#    'html_url': 'https://github.com/DiSanchz',
#    'followers_url': 'https://api.github.com/users/DiSanchz/followers',
#    'following_url': 'https://api.github.com/users/DiSanchz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DiSanchz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DiSanchz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DiSanchz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DiSanchz/orgs',
#    'repos_url': 'https://api.github.com/users/DiSanchz/repos',
#    'events_url': 'https://api.github.com/users/DiSanchz/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DiSanchz/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/DiSanchz/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/DiSanchz/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/DiSanchz/apuntes_clase/deployments',
#   'created_at': '2022-01-18T08:21:51Z',
#   'updated_at': '2022-01-10T12:36:54Z',
#   'pushed_at': '2022-01-17T17:12:38Z',
#   'git_url': 'git://github.com/DiSanchz/apuntes_clase.git',
#   'ssh_url': 'git@github.com:DiSanchz/apuntes_clase.git',
#   'clone_url': 'https://github.com/DiSanchz/apuntes_clase.git',
#   'svn_url': 'https://github.com/DiSanchz/apuntes_clase',
#   'homepage': None,
#   'size': 24611,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 447276463,
#   'node_id': 'R_kgDOGqjlrw',
#   'name': 'apuntes_clase',
#   'full_name': 'jesuschao/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'jesuschao',
#    'id': 94131027,
#    'node_id': 'U_kgDOBZxTUw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94131027?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jesuschao',
#    'html_url': 'https://github.com/jesuschao',
#    'followers_url': 'https://api.github.com/users/jesuschao/followers',
#    'following_url': 'https://api.github.com/users/jesuschao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jesuschao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jesuschao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jesuschao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jesuschao/orgs',
#    'repos_url': 'https://api.github.com/users/jesuschao/repos',
#    'events_url': 'https://api.github.com/users/jesuschao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jesuschao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/jesuschao/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/jesuschao/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/jesuschao/apuntes_clase/deployments',
#   'created_at': '2022-01-12T15:46:36Z',
#   'updated_at': '2022-01-13T10:51:47Z',
#   'pushed_at': '2022-01-14T14:38:17Z',
#   'git_url': 'git://github.com/jesuschao/apuntes_clase.git',
#   'ssh_url': 'git@github.com:jesuschao/apuntes_clase.git',
#   'clone_url': 'https://github.com/jesuschao/apuntes_clase.git',
#   'svn_url': 'https://github.com/jesuschao/apuntes_clase',
#   'homepage': None,
#   'size': 24577,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 447190248,
#   'node_id': 'R_kgDOGqeU6A',
#   'name': 'apuntes_clase',
#   'full_name': 'SergioMB12/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'SergioMB12',
#    'id': 95930832,
#    'node_id': 'U_kgDOBbfJ0A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95930832?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SergioMB12',
#    'html_url': 'https://github.com/SergioMB12',
#    'followers_url': 'https://api.github.com/users/SergioMB12/followers',
#    'following_url': 'https://api.github.com/users/SergioMB12/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SergioMB12/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SergioMB12/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SergioMB12/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SergioMB12/orgs',
#    'repos_url': 'https://api.github.com/users/SergioMB12/repos',
#    'events_url': 'https://api.github.com/users/SergioMB12/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SergioMB12/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/SergioMB12/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/SergioMB12/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/SergioMB12/apuntes_clase/deployments',
#   'created_at': '2022-01-12T11:24:30Z',
#   'updated_at': '2022-01-12T14:50:41Z',
#   'pushed_at': '2022-01-14T13:00:52Z',
#   'git_url': 'git://github.com/SergioMB12/apuntes_clase.git',
#   'ssh_url': 'git@github.com:SergioMB12/apuntes_clase.git',
#   'clone_url': 'https://github.com/SergioMB12/apuntes_clase.git',
#   'svn_url': 'https://github.com/SergioMB12/apuntes_clase',
#   'homepage': None,
#   'size': 24577,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 446880118,
#   'node_id': 'R_kgDOGqLZdg',
#   'name': 'apuntes_clase',
#   'full_name': 'sergiomessaoudi/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'sergiomessaoudi',
#    'id': 96984188,
#    'node_id': 'U_kgDOBcfcfA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96984188?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sergiomessaoudi',
#    'html_url': 'https://github.com/sergiomessaoudi',
#    'followers_url': 'https://api.github.com/users/sergiomessaoudi/followers',
#    'following_url': 'https://api.github.com/users/sergiomessaoudi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sergiomessaoudi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sergiomessaoudi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sergiomessaoudi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sergiomessaoudi/orgs',
#    'repos_url': 'https://api.github.com/users/sergiomessaoudi/repos',
#    'events_url': 'https://api.github.com/users/sergiomessaoudi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sergiomessaoudi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/sergiomessaoudi/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/sergiomessaoudi/apuntes_clase/deployments',
#   'created_at': '2022-01-11T15:37:38Z',
#   'updated_at': '2022-01-12T15:30:20Z',
#   'pushed_at': '2022-01-12T15:30:15Z',
#   'git_url': 'git://github.com/sergiomessaoudi/apuntes_clase.git',
#   'ssh_url': 'git@github.com:sergiomessaoudi/apuntes_clase.git',
#   'clone_url': 'https://github.com/sergiomessaoudi/apuntes_clase.git',
#   'svn_url': 'https://github.com/sergiomessaoudi/apuntes_clase',
#   'homepage': None,
#   'size': 16994,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 446879337,
#   'node_id': 'R_kgDOGqLWaQ',
#   'name': 'apuntes_clase',
#   'full_name': 'JuanaMG/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'JuanaMG',
#    'id': 73229521,
#    'node_id': 'MDQ6VXNlcjczMjI5NTIx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73229521?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JuanaMG',
#    'html_url': 'https://github.com/JuanaMG',
#    'followers_url': 'https://api.github.com/users/JuanaMG/followers',
#    'following_url': 'https://api.github.com/users/JuanaMG/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JuanaMG/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JuanaMG/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JuanaMG/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JuanaMG/orgs',
#    'repos_url': 'https://api.github.com/users/JuanaMG/repos',
#    'events_url': 'https://api.github.com/users/JuanaMG/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JuanaMG/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/JuanaMG/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/JuanaMG/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/JuanaMG/apuntes_clase/statuses/{sha}',
# ...
#    'events_url': 'https://api.github.com/users/beihglez/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/beihglez/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/beihglez/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/beihglez/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/beihglez/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/beihglez/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/beihglez/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/beihglez/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/beihglez/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/beihglez/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/beihglez/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/beihglez/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/beihglez/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/beihglez/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/beihglez/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/beihglez/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/beihglez/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/beihglez/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/beihglez/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/beihglez/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/beihglez/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/beihglez/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/beihglez/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/beihglez/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/beihglez/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/beihglez/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/beihglez/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/beihglez/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/beihglez/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/beihglez/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/beihglez/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/beihglez/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/beihglez/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/beihglez/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/beihglez/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/beihglez/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/beihglez/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/beihglez/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/beihglez/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/beihglez/apuntes_clase/deployments',
#   'created_at': '2022-01-11T08:10:23Z',
#   'updated_at': '2022-01-10T12:36:54Z',
#   'pushed_at': '2022-01-11T08:08:29Z',
#   'git_url': 'git://github.com/beihglez/apuntes_clase.git',
#   'ssh_url': 'git@github.com:beihglez/apuntes_clase.git',
#   'clone_url': 'https://github.com/beihglez/apuntes_clase.git',
#   'svn_url': 'https://github.com/beihglez/apuntes_clase',
#   'homepage': None,
#   'size': 16917,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 446731580,
#   'node_id': 'R_kgDOGqCVPA',
#   'name': 'apuntes_clase',
#   'full_name': 'IsabelGarcia11/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'IsabelGarcia11',
#    'id': 96237624,
#    'node_id': 'U_kgDOBbx4OA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96237624?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IsabelGarcia11',
#    'html_url': 'https://github.com/IsabelGarcia11',
#    'followers_url': 'https://api.github.com/users/IsabelGarcia11/followers',
#    'following_url': 'https://api.github.com/users/IsabelGarcia11/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/IsabelGarcia11/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/IsabelGarcia11/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/IsabelGarcia11/subscriptions',
#    'organizations_url': 'https://api.github.com/users/IsabelGarcia11/orgs',
#    'repos_url': 'https://api.github.com/users/IsabelGarcia11/repos',
#    'events_url': 'https://api.github.com/users/IsabelGarcia11/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/IsabelGarcia11/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/IsabelGarcia11/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/IsabelGarcia11/apuntes_clase/deployments',
#   'created_at': '2022-01-11T08:10:07Z',
#   'updated_at': '2022-01-10T12:36:54Z',
#   'pushed_at': '2022-01-11T08:08:29Z',
#   'git_url': 'git://github.com/IsabelGarcia11/apuntes_clase.git',
#   'ssh_url': 'git@github.com:IsabelGarcia11/apuntes_clase.git',
#   'clone_url': 'https://github.com/IsabelGarcia11/apuntes_clase.git',
#   'svn_url': 'https://github.com/IsabelGarcia11/apuntes_clase',
#   'homepage': None,
#   'size': 16917,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}},
#  {'id': 446394415,
#   'node_id': 'R_kgDOGptwLw',
#   'name': 'apuntes_clase',
#   'full_name': 'evaarquero/apuntes_clase',
#   'private': False,
#   'owner': {'login': 'evaarquero',
#    'id': 96523353,
#    'node_id': 'U_kgDOBcDUWQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96523353?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/evaarquero',
#    'html_url': 'https://github.com/evaarquero',
#    'followers_url': 'https://api.github.com/users/evaarquero/followers',
#    'following_url': 'https://api.github.com/users/evaarquero/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/evaarquero/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/evaarquero/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/evaarquero/subscriptions',
#    'organizations_url': 'https://api.github.com/users/evaarquero/orgs',
#    'repos_url': 'https://api.github.com/users/evaarquero/repos',
#    'events_url': 'https://api.github.com/users/evaarquero/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/evaarquero/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/evaarquero/apuntes_clase',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/evaarquero/apuntes_clase',
#   'forks_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/forks',
#   'keys_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/teams',
#   'hooks_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/hooks',
#   'issue_events_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/events',
#   'assignees_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/tags',
#   'blobs_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/languages',
#   'stargazers_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/stargazers',
#   'contributors_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/contributors',
#   'subscribers_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/subscribers',
#   'subscription_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/subscription',
#   'commits_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/merges',
#   'archive_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/downloads',
#   'issues_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/evaarquero/apuntes_clase/deployments',
#   'created_at': '2022-01-10T11:24:19Z',
#   'updated_at': '2022-01-11T08:23:44Z',
#   'pushed_at': '2022-02-02T10:30:15Z',
#   'git_url': 'git://github.com/evaarquero/apuntes_clase.git',
#   'ssh_url': 'git@github.com:evaarquero/apuntes_clase.git',
#   'clone_url': 'https://github.com/evaarquero/apuntes_clase.git',
#   'svn_url': 'https://github.com/evaarquero/apuntes_clase',
#   'homepage': None,
#   'size': 60868,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': False,
#    'maintain': False,
#    'push': False,
#    'triage': False,
#    'pull': True}}]

# %%
'''We realize that each element of the list is a dictionary with the information of a forked repository, 
inside it we need to get the language trough the key 'language_url' and then iterate through the list of url'''
idiomas = [idioma["languages_url"] for idioma in forks]
idiomasp = [re.findall(r"/repos.*", idioma)for idioma in idiomas]
listaidiomas = [i[0] for i in idiomasp]

# %%
idiomas_json = list(map(requestGithub,listaidiomas))
# Out:
# Haciendo request a https://api.github.com/repos/VictorPablo12/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/Marilyn499/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/AntonioLopga12/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/mariozapatero/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/DiSanchz/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/jesuschao/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/SergioMB12/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/sergiomessaoudi/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/JuanaMG/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/ce-valle/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/Pomilusky/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/rodrigogalan/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/pablomora213/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/beihglez/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/IsabelGarcia11/apuntes_clase/languages
# Haciendo request a https://api.github.com/repos/evaarquero/apuntes_clase/languages

# %%
set([lenguaje for e in idiomas_json for lenguaje in e.keys()]) #to get only the unique values
# Out:
# {'Jupyter Notebook', 'Python'}
